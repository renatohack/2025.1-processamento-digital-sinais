# %%
from IPython.display import display
from PIL import Image

# %%
img = Image.open("q1.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=627x558>

# %% [markdown]
# ### a)
#
# x(t) = A.sen(2.π.f.t + ϕ)
#
# Para o sinal dado, f = 2Hz (completa 2 ciclos em 1 segundo), logo
#
# x(t) = 3.sen(2.π.2.t + 0) = 3.sen(4.π.t)
#
# ### b)
#
# O período é dado por T = 1/f = 1/2 = 0,5s.

# %%
img = Image.open("q2.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=565x558>

# %%
img = Image.open("q3.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=588x174>

# %%
img = Image.open("q4.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=583x205>
